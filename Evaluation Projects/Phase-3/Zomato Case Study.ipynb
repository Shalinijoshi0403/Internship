# %% [markdown]
# # Zomato Restaurant
# ## Project Description
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# #### Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# - Country code
# - Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
# - Restaurant Id: Unique id of every restaurant across various cities of the world
# - Restaurant Name: Name of the restaurant
# - Country Code: Country in which restaurant is located
# - City: City in which restaurant is located
# - Address: Address of the restaurant
# - Locality: Location in the city
# - Locality Verbose: Detailed description of the locality
# - Longitude: Longitude coordinate of the restaurant&#39;s location
# - Latitude: Latitude coordinate of the restaurant&#39;s location
# - Cuisines: Cuisines offered by the restaurant
# - Average Cost for two: Cost for two people in different currencies ��
# - Currency: Currency of the country
# - Has Table booking: yes/no
# - Has Online delivery: yes/ no
# - Is delivering: yes/ no
# - Switch to order menu: yes/no
# - Price range: range of price of food
# - Aggregate Rating: Average rating out of 5
# - Rating color: depending upon the average rating color
# - Rating text: text on the basis of rating of rating
# - Votes: Number of ratings casted by people
#
# #### Problem statement : In this dataset predict 2 things –
# - 1) Average Cost for two
# - 2) Price range
#
#
# #### Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets
#
#
# #### Dataset Link-
# •	https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
# •	https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv("C:\\Users\\suven\\OneDrive\\Desktop\\Internship\\Evaluation Projects\\Third Phase\\Zomato\\zomato.csv",encoding = 'unicode_escape', engine ='python')

# %%
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
# Also importing the country code csv file
country_code=pd.read_excel("C:\\Users\\suven\\OneDrive\\Desktop\\Internship\\Evaluation Projects\\Third Phase\\Zomato\\Country-Code.xlsx")

# %%
country_code.head(2)
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia

# %%
# merge both dataset to one DataFrame
df=pd.merge(df,country_code,on='Country Code',how='left')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# checking rows and columns
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# - There are 9551 rows and 22 columns in the dataset

# %%
# seeing all column names at a glance
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# checking datatypes of columns
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# - There are 14 categorical fields and 8 numerical fields

# %%
# seeing more info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# - There are 9551 rows and 22 columns in the dataset
# - There are 14 categorical fields and 8 numerical fields
# - Only Cuisines have 9 missing values
# - The column header looks appropriate as it matches the datatype shown

# %%
# checking null values again
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# - Only Cuisines have 9 missing values

# %%
# we can delete these records as they are < 1%
df.dropna(inplace=True)
df.shape
# Out:
# (9542, 22)

# %%
# Value counts for every feature to check the missing again or unique values
for i in df.columns:
    print(df[i].value_counts())
    print('**********************************')
# Out:
# 6317637     1
# 18336474    1
# 18382047    1
# 18441566    1
# 18441669    1
#            ..
# 18451576    1
# 580         1
# 308703      1
# 60          1
# 5927402     1
# Name: Restaurant ID, Length: 9542, dtype: int64
# **********************************
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7437, dtype: int64
# **********************************
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
# **********************************
# ...

# %% [markdown]
# - Switch to order menu is constant feature so it can be removed from the dataset.
# - Restaurant ID feature has high cardinality so it can be removed.
# - Locality Verbose and Locality features are similar. Therefore dropping Locality Verbose.
# - Country Code feature can be removed as we have country name now (after merging two datasets).

# %%
#Droping unnecessary columns from as shown above.
df.drop(['Restaurant ID','Switch to order menu','Locality Verbose','Country Code'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9542, 18)

# %%
# statistical summary of dataset
df.describe()
# Out:
#          Longitude     Latitude  Average Cost for two  Price range  \
# count  9542.000000  9542.000000           9542.000000  9542.000000
# mean     64.274997    25.848532           1200.326137     1.804968
# std      41.197602    11.010094          16128.743876     0.905563
# min    -157.948486   -41.330428              0.000000     1.000000
# 25%      77.081565    28.478658            250.000000     1.000000
# 50%      77.192031    28.570444            400.000000     2.000000
# 75%      77.282043    28.642711            700.000000     2.000000
# max     174.832089    55.976980         800000.000000     4.000000
#
#        Aggregate rating         Votes
# count       9542.000000   9542.000000
# mean           2.665238    156.772060
# std            1.516588    430.203324
# min            0.000000      0.000000
# 25%            2.500000      5.000000
# 50%            3.200000     31.000000
# 75%            3.700000    130.000000
# max            4.900000  10934.000000

# %% [markdown]
# - some columns are skewed
# - Some columns seem to have outliers

# %%
# checking skewness
df.skew()
# Out:
# Longitude               -2.819828
# Latitude                -3.081780
# Average Cost for two    35.461264
# Price range              0.889879
# Aggregate rating        -0.953052
# Votes                    8.813270
# dtype: float64

# %% [markdown]
# - There is skewness in most of the columns. We will deal with it going forward.

# %%
# check duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - No duplicate records

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Univariate analysis

# %%
# Let's visualise numerical fields on the histplot

# plotting for numerical columns only
plt.figure(figsize=(15,10))
for i in enumerate(df.select_dtypes(include=['int64', 'float64', 'int32'])):
    plt.subplot(2,3,i[0]+1)
    sns.distplot(df[i[1]],color='blue')

# %% [markdown]
# - All columns show skewness

# %%
df.dtypes
# Out:
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# Let's visualise categorical fields on the countplot

cat=df.select_dtypes(include=['object'])

# %%
for i in cat.columns.difference(['Restaurant Name','Cuisines','City','Address','Locality']):
    plt.figure(figsize=(20,12))
    sns.countplot(cat[i])
    plt.show()

# %% [markdown]
# Most restaurants in the dataset are from india (90%).
#
# Most restaurants have niether online delivery nor table booking.
#
# Since India has the largest numbers of restaurants, so will analyse India.

# %% [markdown]
# ### Bivariate analysis

# %%
# country vs cities
df.groupby(['Country'])['City'].nunique().sort_values(ascending=False).plot(kind='bar',legend=True)
plt.show()

# %% [markdown]
# Zomato is present in 43 cities in India and 35 in the USA and 23 in Australia and the rest are the 12 cities. So it validates the previous assumption that India and USA can be compared.

# %%
# USA ratings
d=df[df['Country']=='United States']
sns.histplot(d['Aggregate rating'])
plt.show()

# %%
# India ratings
d=df[df['Country']=='India']
sns.histplot(d['Aggregate rating'])
plt.show()

# %% [markdown]
# USA restaurants have higher ratings compared with Indian restaurants, this could indicate a better service in the US. A major of Indian restaurant ratings are zero.

# %%
# USA Votes
d=df[df['Country']=='United States']
sns.displot(d['Votes'])
plt.show()

# %%
# India Votes
d=df[df['Country']=='India']
sns.histplot(d['Votes'],bins=100)
plt.show()

# %% [markdown]
# We check the rating count in the Indian subcontinent vs the US. US customers have a higher vote count than Indians, reiterating the previous finding of ratings

# %%
# USA cuisines
d=df[df['Country']=='United States']
d['Cuisines'].value_counts().head(10).plot(kind='bar',legend=True)
plt.show()

# %%
# India cuisines
d=df[df['Country']=='India']
d['Cuisines'].value_counts().head(10).plot(kind='bar',legend=True)
plt.show()

# %% [markdown]
# North Indian, Chinese, Fast food, Mughlai are a few popular cuisines in India, so new restaurants opening up in this space can face stiff competition from established restaurants. The potential for growth in south Indian cuisines seems good due to the lack of competition and variety of vegetarian dishes.
#
# Americans love everything American – steak, seafood, burgers, BBQ apart from Mexican and Chinese food.

# %% [markdown]
# ##### India is the dominant in this dataset so i will do will consider it now for my model.

# %%
data=df[df['Country']=='India']
data.head()
# Out:
#                            Restaurant Name  City  \
# 624                             Jahanpanah  Agra
# 625                    Rangrezz Restaurant  Agra
# 626                Time2Eat - Mama Chicken  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 628                         Pinch Of Spice  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#      Longitude   Latitude                        Cuisines  \
# 624  78.011544  27.161661           North Indian, Mughlai
# 625   0.000000   0.000000           North Indian, Mughlai
# 626  78.011608  27.160832                    North Indian
# ...

# %%
data.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2139
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    26
# 6                2.3          Red        Poor    46
# 7                2.4          Red        Poor    83
# 8                2.5       Orange     Average   109
# 9                2.6       Orange     Average   190
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   314
# 12               2.9       Orange     Average   380
# 13               3.0       Orange     Average   465
# 14               3.1       Orange     Average   511
# 15               3.2       Orange     Average   510
# 16               3.3       Orange     Average   472
# ...

# %%
# Ratings

top_rated=data[data['Aggregate rating']>4.4]
low_rated=data[data['Aggregate rating']<3.5]

# %%
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# top rated restauranys 
figure=px.bar(top_rated,x='City',y='Aggregate rating')
figure.show()
# Out:
# <div>                            <div id="66f41473-e767-4302-9f87-fb28131d4531" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66f41473-e767-4302-9f87-fb28131d4531")) {                    Plotly.newPlot(                        "66f41473-e767-4302-9f87-fb28131d4531",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}<br>Aggregate rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Agra","Ahmedabad","Ahmedabad","Ahmedabad","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bhopal","Bhubaneshwar","Bhubaneshwar","Chandigarh","Chandigarh
# ...

# %%
# low rated restaurants 
figure=px.bar(low_rated,x='City',y='Aggregate rating')
figure.show()
# Out:
# <div>                            <div id="b528bd2b-bee9-483b-8934-5d043b7f13cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b528bd2b-bee9-483b-8934-5d043b7f13cf")) {                    Plotly.newPlot(                        "b528bd2b-bee9-483b-8934-5d043b7f13cf",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}<br>Aggregate rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Agra","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Amritsar","Amritsar","Amri
# ...

# %%
# city wise 
figure=px.scatter(low_rated,x='City',y='Aggregate rating',color='Rating color')
figure.show()
# Out:
# <div>                            <div id="86a954b7-4b6d-4787-8d55-37c2e189c370" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86a954b7-4b6d-4787-8d55-37c2e189c370")) {                    Plotly.newPlot(                        "86a954b7-4b6d-4787-8d55-37c2e189c370",                        [{"hovertemplate":"Rating color=Orange<br>City=%{x}<br>Aggregate rating=%{y}<extra></extra>","legendgroup":"Orange","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Orange","showlegend":true,"x":["Agra","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Aurang
# ...

# %%
# top rated restaurants on map

fig=px.scatter_mapbox(top_rated,lat='Latitude',lon='Longitude',hover_name='City',hover_data=
                      ['Aggregate rating','Restaurant Name'], color_discrete_sequence=['fuchsia'], zoom=5, height=300)
fig.update_layout(mapbox_style='open-street-map')
fig.update_layout(title='Highly rated Restaurants locations',autosize=True,hovermode='closest',showlegend=False)
fig.update_layout(autosize=False,width=800,height=500)
fig.show()
# Out:
# <div>                            <div id="0ff1f755-cb2d-40a3-b1d9-18acf3175b9e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ff1f755-cb2d-40a3-b1d9-18acf3175b9e")) {                    Plotly.newPlot(                        "0ff1f755-cb2d-40a3-b1d9-18acf3175b9e",                        [{"customdata":[[4.9,"Sheroes Hangout"],[4.5,"Huber & Holly"],[4.6,"Cryo Lab"],[4.5,"Nini's Kitchen"],[4.7,"The Fatty Bao - Asian Gastro Bar"],[4.8,"Toit"],[4.6,"Onesta"],[4.7,"ECHOES Koramangala"],[4.7,"Truffles"],[4.5,"Koramangala Social"],[4.6,"AB's - Absolute Barbecues"],[4.6,"Onesta"],[4.5,"Big Brewsky"],[4.9,"Sagar Gaire Fast Food"],[4.6,"Barbeque Nation"],[4.5,"Central Perk 7"],[4.5,"Barbeque Nation"],[4.5,"Burgrill"],[4.8,"Chili's"],[4.6,"Fusilli Reasons"
# ...

# %% [markdown]
# # Outlier treatment

# %%
num=df.select_dtypes(include=['float64','int64'])

# %%
# Check outliers using boxplot
for col in num.columns.difference(['Longitude','Latitude']):
    sns.boxplot(data[col])
    plt.show()

# %%
# use Z-score method
from scipy.stats import zscore
outliers=data[num.columns.difference(['Longitude','Latitude'])]
z=np.abs(zscore(outliers))
df_new=data[(z<3).all(axis=1)]
df_new.shape
# Out:
# (8326, 18)

# %%
# data loss percentage

loss_percentage= ((data.shape[0]- df_new.shape[0])/data.shape[0])*100
loss_percentage
# Out:
# 3.7679149329634765

# %% [markdown]
# - It's acceptable

# %%
# Check Skewness
df_new.skew()
# Out:
# Longitude              -3.691142
# Latitude               -3.232362
# Average Cost for two    1.740235
# Price range             0.977583
# Aggregate rating       -0.849235
# Votes                   3.700299
# dtype: float64

# %%
# I'll consider -0.5/0.5 is ok among features skewness and treat the others features.

skew_cols=['Average Cost for two','Price range','Aggregate rating','Votes']

# %%
# withing Power transformer to treat skewness
from sklearn.preprocessing import StandardScaler,PowerTransformer
scaler = PowerTransformer()
df_new[skew_cols] = scaler.fit_transform(df_new[skew_cols].values)

# %%
df_new.columns
# Out:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# drop unnecessary columns
df_new.drop(columns=['Restaurant Name','Is delivering now','Address','Locality','Currency','Country'],axis=1,inplace=True)

# %%
# Encoding

# use getdummies for nominal features like; gelocation source and other fuel, while use ordinal encoder for target feature

#Encoding the target feature:

encode_cols=["City","Cuisines"]


from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

for i in encode_cols:
    df_new[i]=enc.fit_transform(df_new[i].values.reshape(-1,1))
    
df_new=pd.get_dummies(df_new,columns=['Has Table booking','Has Online delivery','Rating color', 'Rating text'],drop_first=True)

# %%
df_new.head()
# Out:
#      City  Longitude   Latitude  Cuisines  Average Cost for two  Price range  \
# 624   0.0  78.011544  27.161661    1070.0              0.949893     1.463471
# 625   0.0   0.000000   0.000000    1070.0              0.645136     0.777773
# 626   0.0  78.011608  27.160832     874.0              0.138808     0.777773
# 627   0.0  77.998092  27.195928    1182.0             -0.182290     0.777773
# 628   0.0  78.007553  27.201725     939.0              1.212326     1.463471
#
#      Aggregate rating     Votes  Has Table booking_Yes  \
# 624          1.060167  1.006844                      0
# 625          0.686215  0.650847                      0
# 626          0.777737  0.797424                      0
# 627          1.156902  0.756917                      0
# 628          1.354203  1.130769                      0
#
#      Has Online delivery_Yes  Rating color_Green  Rating color_Orange  \
# 624                        0                   0                    0
# ...

# %%
# heatmap correlation
plt.figure(figsize = (20,10))
sns.heatmap(df_new.corr(), annot=True,cmap='summer',fmt='.2f')
plt.show()

# %%
#Visualization of the Correlation Metrics for using (Average cost for 2) as target feature
plt.figure(figsize = (25, 15))

df_new.corr()['Average Cost for two'].sort_values(ascending = False).drop(['Average Cost for two']).plot(kind = 'bar', color = 'c')

plt.xlabel('Feature', fontsize = 20)

plt.ylabel('Target', fontsize = 20)

plt.title('Correlation', fontsize = 20)

plt.show()

# %% [markdown]
# Price rating is strong postive correlation withe the target.
#
# Cusinies and latitude are least correlations.
#
# Rating colcor_white is the most negative correlation.

# %%
#Visualization of the Correlation Metrics for using (Price range)) as target feature
plt.figure(figsize = (25, 15))

df_new.corr()['Price range'].sort_values(ascending = False).drop(['Price range']).plot(kind = 'bar', color = 'c')

plt.xlabel('Feature', fontsize = 20)

plt.ylabel('Target', fontsize = 20)

plt.title('Correlation', fontsize = 20)

plt.show()

# %% [markdown]
# - Average cost for two `is strong postive correlation withe the target.

# %% [markdown]
# # Part 1: Regression Problem  for 'Average cost for two'

# %%
# Average Cost for two is the target feature now.
x = df_new.drop('Average Cost for two',axis=1)
y = df_new['Average Cost for two']

# %%
#standardising features
sc= StandardScaler()
x = pd.DataFrame(sc.fit_transform(x), columns = x.columns)
x
# Out:
#           City  Longitude  Latitude  Cuisines  Price range  Aggregate rating  \
# 0    -3.717960   0.290958  0.106622  1.043113     1.463471          1.060167
# 1    -3.717960  -3.963475 -3.741286  1.043113     0.777773          0.686215
# 2    -3.717960   0.290962  0.106504  0.521909     0.777773          0.777737
# 3    -3.717960   0.290225  0.111476  1.340944     0.777773          1.156902
# 4    -3.717960   0.290741  0.112298  0.694757     1.463471          1.354203
# ...        ...        ...       ...       ...          ...               ...
# 8321  1.933352   0.582717 -1.224675 -0.499226     0.777773          0.777737
# 8322  1.933352  -3.963475 -3.741286 -1.108184     0.777773          0.870575
# 8323  1.933352   0.580203 -1.231014 -1.403355     0.777773          1.454753
# 8324  1.933352   0.581378 -1.230781 -1.722460     1.812399          0.964722
# 8325  1.933352   0.580184 -1.230790 -0.020569     1.463471          1.556557
#
# ...

# %%
# checking multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.057554                     City
# 1       9.620009                Longitude
# 2       9.818847                 Latitude
# 3       1.026128                 Cuisines
# 4       1.666278              Price range
# 5      43.392363         Aggregate rating
# 6       5.271589                    Votes
# 7       1.326933    Has Table booking_Yes
# 8       1.260550  Has Online delivery_Yes
# 9            inf       Rating color_Green
# 10           inf      Rating color_Orange
# 11           inf         Rating color_Red
# 12           inf       Rating color_White
# 13           inf      Rating color_Yellow
# 14           inf    Rating text_Excellent
# 15           inf         Rating text_Good
# 16           inf    Rating text_Not rated
# 17           inf         Rating text_Poor
# 18           inf    Rating text_Very Good

# %%
x = x.drop(['Rating text_Very Good','Rating text_Poor'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.057554                     City
# 1       9.620009                Longitude
# 2       9.818847                 Latitude
# 3       1.026128                 Cuisines
# 4       1.666278              Price range
# 5      43.392363         Aggregate rating
# 6       5.271589                    Votes
# 7       1.326933    Has Table booking_Yes
# 8       1.260550  Has Online delivery_Yes
# 9            inf       Rating color_Green
# 10           inf      Rating color_Orange
# 11           inf         Rating color_Red
# 12           inf       Rating color_White
# 13           inf      Rating color_Yellow
# 14           inf    Rating text_Excellent
# 15           inf         Rating text_Good
# 16           inf    Rating text_Not rated

# %%
x = x.drop(['Rating color_Green','Rating text_Not rated'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.057554                     City
# 1       9.620009                Longitude
# 2       9.818847                 Latitude
# 3       1.026128                 Cuisines
# 4       1.666278              Price range
# 5      43.392363         Aggregate rating
# 6       5.271589                    Votes
# 7       1.326933    Has Table booking_Yes
# 8       1.260550  Has Online delivery_Yes
# 9      14.768619      Rating color_Orange
# 10      3.520713         Rating color_Red
# 11     68.736586       Rating color_White
# 12           inf      Rating color_Yellow
# 13      1.246935    Rating text_Excellent
# 14           inf         Rating text_Good

# %%
x = x.drop(['Rating color_Yellow'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.057554                     City
# 1       9.620009                Longitude
# 2       9.818847                 Latitude
# 3       1.026128                 Cuisines
# 4       1.666278              Price range
# 5      43.392363         Aggregate rating
# 6       5.271589                    Votes
# 7       1.326933    Has Table booking_Yes
# 8       1.260550  Has Online delivery_Yes
# 9      14.768619      Rating color_Orange
# 10      3.520713         Rating color_Red
# 11     68.736586       Rating color_White
# 12      1.246935    Rating text_Excellent
# 13      4.644523         Rating text_Good

# %%
x = x.drop(['Aggregate rating'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.055961                     City
# 1       9.617529                Longitude
# 2       9.808818                 Latitude
# 3       1.022109                 Cuisines
# 4       1.666260              Price range
# 5       5.027186                    Votes
# 6       1.326879    Has Table booking_Yes
# 7       1.256377  Has Online delivery_Yes
# 8       5.864436      Rating color_Orange
# 9       1.374775         Rating color_Red
# 10      8.986044       Rating color_White
# 11      1.152205    Rating text_Excellent
# 12      3.377740         Rating text_Good

# %% [markdown]
# - this looks fine now!

# %%
# Removing skewness
from sklearn.preprocessing import power_transform
X=power_transform(x, method='yeo-johnson')
X
# Out:
# array([[-2.06294152,  0.40548405, -1.00138462, ..., -0.58742889,
#         -0.10095396,  1.95905205],
#        [-2.06294152, -2.84508712, -2.55535419, ..., -0.58742889,
#         -0.10095396,  1.95905205],
#        [-2.06294152,  0.40550814, -1.00191499, ..., -0.58742889,
#         -0.10095396,  1.95905205],
#        ...,
#        [ 6.37418376,  3.13599318, -2.43627343, ..., -0.58742889,
#         -0.10095396, -0.51045096],
#        [ 6.37418376,  3.15040686, -2.43623518, ..., -0.58742889,
#         -0.10095396,  1.95905205],
#        [ 6.37418376,  3.13576632, -2.43623664, ..., -0.58742889,
#         -0.10095396, -0.51045096]])

# %%
#checking for skewness is removed or not
skew_df=pd.DataFrame(X)
skew_df.skew()
# Out:
# 0     0.693326
# 1     2.581545
# 2     1.425181
# 3    -0.040039
# 4     0.167827
# 5     0.019632
# 6     2.504879
# 7     0.963153
# 8     0.256267
# 9     6.619132
# 10    1.115106
# 11    9.806319
# 12    1.448862
# dtype: float64

# %% [markdown]
# - skewness is treated now.It cant be reduced furthermore.

# %%
# Importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Finding the best Random State
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.7538669006512417
# testing accuracy is  0.7670276509525092
#
#
# Random State is  1
# training accuracy is  0.7561628383681634
# testing accuracy is  0.7573882347203965
#
#
# Random State is  2
# training accuracy is  0.7496725715858739
# testing accuracy is  0.7844877884214436
#
#
# Random State is  3
# training accuracy is  0.7606876125361144
# testing accuracy is  0.7383526940898608
#
#
# Random State is  4
# training accuracy is  0.7572117374599644
# testing accuracy is  0.7532437581742129
#
#
# Random State is  5
# training accuracy is  0.7592237083099036
# testing accuracy is  0.7446805463745476
#
#
# Random State is  6
# training accuracy is  0.757444511451249
# testing accuracy is  0.7527310273967396
#
#
# Random State is  7
# training accuracy is  0.7533912536300633
# testing accuracy is  0.7693931861405494
#
#
# Random State is  8
# training accuracy is  0.752851755315903
# testing accuracy is  0.77248261158776
#
#
# ...

# %% [markdown]
# maximum r2 score is  0.7879647880275873 at random state  40

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=40)
print("shape of x_train is: ",x_train.shape)
print("shape of y_train is: ",y_train.shape)
print("shape of x_test is: ",x_test.shape)
print("shape of y_test is: ",y_test.shape)
# Out:
# shape of x_train is:  (6660, 13)
# shape of y_train is:  (6660,)
# shape of x_test is:  (1666, 13)
# shape of y_test is:  (1666,)

# %% [markdown]
# # 1. Linear Regression

# %%
lr.fit(x_train,y_train)
y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,y_train_pred))
print('testing accuracy is ', r2_score(y_test,y_test_pred))
print("Mean Squared Error is ",mean_squared_error(y_test,y_test_pred))
print("Mean Absolute Error is ",mean_absolute_error(y_test,y_test_pred))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred)))
# Out:
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# Mean Squared Error is  0.2245410029430913
# Mean Absolute Error is  0.3801857400855798
# Root Mean Squared Error is  0.47385757664417616

# %%
from sklearn.model_selection import cross_val_score
#cross validation of the lr model
for j in range(2,20):
    cv_score = cross_val_score(lr,x,y,cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,y_train_pred))
    print('testing accuracy is ', r2_score(y_test,y_test_pred))
# Out:
# At fold  2 Mean CV score is  0.7092926952364873
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  3 Mean CV score is  0.7104784135615736
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  4 Mean CV score is  0.7139350552340222
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  5 Mean CV score is  0.7321477166444739
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  6 Mean CV score is  0.7442316588401123
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  7 Mean CV score is  0.7464144487030365
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  8 Mean CV score is  0.7437507448550538
# training accuracy is  0.7375237988733876
# testing accuracy is  0.7763315183920159
# At fold  9 Mean CV score is  0.7438092660875317
# ...

# %% [markdown]
# # 2. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
y_train_pred_dtr = dtr.predict(x_train)
y_test_pred_dtr = dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train, y_train_pred_dtr))
print('testing accuracy is ', r2_score(y_test, y_test_pred_dtr))
print('Mean squared error is ', mean_squared_error(y_test,y_test_pred_dtr))
print('Mean Absolute error is ', mean_absolute_error(y_test,y_test_pred_dtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred_dtr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.9852615555453318
# Mean squared error is  0.014909575089359
# Mean Absolute error is  0.013644281883977065
# Root Mean Squared Error is  0.12210477095248572

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cv_dtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_dtr.mean())
# Out:
# At fold  2 Mean CV score is  0.9736663866572116
# At fold  3 Mean CV score is  0.9743484115050367
# At fold  4 Mean CV score is  0.9731170405125431
# At fold  5 Mean CV score is  0.9739222550751763
# At fold  6 Mean CV score is  0.9710882458572575
# At fold  7 Mean CV score is  0.972556738187985
# At fold  8 Mean CV score is  0.9746033820783425
# At fold  9 Mean CV score is  0.9734475651671356

# %% [markdown]
# # 3. RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)
y_train_pred_rfr = rfr.predict(x_train)
y_test_pred_rfr = rfr.predict(x_test)
print("training accuracy is ",r2_score(y_train,y_train_pred_rfr))
print("testing accuracy is ",r2_score(y_test,y_test_pred_rfr))
print("mean squared error is ",mean_squared_error(y_test, y_test_pred_rfr))
print("mean absolute error is ",mean_absolute_error(y_test, y_test_pred_rfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred_rfr)))
# Out:
# training accuracy is  0.9990262376552509
# testing accuracy is  0.989495150895401
# mean squared error is  0.01062682272943649
# mean absolute error is  0.01503380865439939
# Root Mean Squared Error is  0.10308648179774343

# %%
# cross validation for random forest model

for j in range(2,10):
    cv_rfr = cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_rfr.mean())
# Out:
# At fold  2 Mean CV score is  0.9776727551111815
# At fold  3 Mean CV score is  0.9775204646412355
# At fold  4 Mean CV score is  0.9774950413498906
# At fold  5 Mean CV score is  0.9724918150048584
# At fold  6 Mean CV score is  0.9793685552958707
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [106], in <cell line: 3>()
#       1 # cross validation for random forest model
#       3 for j in range(2,10):
# ----> 4     cv_rfr = cross_val_score(rfr, x, y, cv=j)
#       5     print('At fold ', j , "Mean CV score is ", cv_rfr.mean())
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# ...

# %% [markdown]
# # 4. ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
y_train_pred_etr = etr.predict(x_train)
y_test_pred_etr = etr.predict(x_test)
print('training accuracy is ',r2_score(y_train, y_train_pred_etr))
print('testing accuracy is ',r2_score(y_test, y_test_pred_etr))
print('mean squared error is ',mean_squared_error(y_test, y_test_pred_etr))
print('mean absolute error is ',mean_absolute_error(y_test, y_test_pred_etr))
print('root mean squared error is ',np.sqrt(mean_squared_error(y_test, y_test_pred_etr)))
# Out:
# training accuracy is  0.998768495485217
# testing accuracy is  0.833717687202536
# mean squared error is  0.16693097310276814
# mean absolute error is  0.29667270373935806
# root mean squared error is  0.4085718701804716

# %%
# cross validation for extra trees regressor model

for j in range(2,10):
    cv_etr = cross_val_score(etr, x, y , cv = j)
    print('At fold ', j , "Mean CV score is ", cv_etr.mean())
# Out:
# At fold  2 Mean CV score is  0.7864061546879616
# At fold  3 Mean CV score is  0.7923370697725387
# At fold  4 Mean CV score is  0.7901211678006355
# At fold  5 Mean CV score is  0.7961963579016815
# At fold  6 Mean CV score is  0.7959648902200674
# At fold  7 Mean CV score is  0.7966702036637325
# At fold  8 Mean CV score is  0.7968928448305558
# At fold  9 Mean CV score is  0.7992292192689164

# %% [markdown]
# # 5. Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
y_train_pred_gbr = gbr.predict(x_train)
y_test_pred_gbr = gbr.predict(x_test)
print('training accuracy is ',r2_score(y_train,y_train_pred_gbr))
print('testing accuracy is ',r2_score(y_test,y_test_pred_gbr))
print('mean squared error is ', mean_squared_error(y_test,y_test_pred_gbr))
print('mean absolute error is ', mean_absolute_error(y_test,y_test_pred_gbr))
print('root mean squared error is ', np.sqrt(mean_squared_error(y_test,y_test_pred_gbr)))
# Out:
# training accuracy is  0.8550720496864601
# testing accuracy is  0.8375719957945242
# mean squared error is  0.16306162901514634
# mean absolute error is  0.2974994063596117
# root mean squared error is  0.4038089016046406

# %%
# cross validation for gradient boosting regressor model

for j in range(2,10):
    cv_gbr = cross_val_score(gbr, x, y, cv=j)
    print('At fold ',j,'Mean cv score is ',cv_gbr.mean())
# Out:
# At fold  2 Mean cv score is  0.8097278032098346
# At fold  3 Mean cv score is  0.8110654629938727
# At fold  4 Mean cv score is  0.8103067825978179
# At fold  5 Mean cv score is  0.8110122326778753
# At fold  6 Mean cv score is  0.8114020924352152
# At fold  7 Mean cv score is  0.8137684168051367
# At fold  8 Mean cv score is  0.8122004688429783
# At fold  9 Mean cv score is  0.8132787527454448

# %% [markdown]
# - The Gradient Boosting Regressor produces the best testing accuracy of 83.7%. So we will finalise it out of all the models.

# %% [markdown]
# # Hyperparameter Tunning

# %%
from sklearn.model_selection import RandomizedSearchCV
parameter = {
    'n_estimators': [100,200,300,400,500],
        'max_features': ['sqrt','log2']
}

model = GradientBoostingRegressor()

rcv = RandomizedSearchCV(model,parameter,cv=9,n_jobs=-1).fit(x_train,y_train.values.ravel())

rcv.best_params_
# Out:
# {'n_estimators': 500, 'max_features': 'log2'}

# %%
# Checking score with best parameter
final_model=ExtraTreesRegressor(max_features='log2',n_estimators=500)
final_model.fit(x_train,y_train)
y_pred_test_final=final_model.predict(x_test)
print('Gradient Boosting Regressor = ',r2_score(y_test,y_pred_test_final))
# Out:
# Gradient Boosting Regressor =  0.8277647868167135

# %%
#saving the model
import joblib
joblib.dump(ExtraTreesRegressor(criterion='mse',max_features='sqrt',n_estimators=300), "Zomato case study.pkl")
# Out:
# ['Zomato case study.pkl']

# %%
# Conclusion
a=np.array(y_test)
predicted=np.array(y_pred_test_final)
df_con=pd.DataFrame({'Original':a,'Predicted':y_pred_test_final}, index=range(len(a)))
df_con
# Out:
#       Original  Predicted
# 0     1.650547   1.870369
# 1    -1.937875  -1.242520
# 2    -1.109421  -1.071725
# 3    -1.937875  -1.007572
# 4     1.212326   0.965903
# ...        ...        ...
# 1661 -0.014232  -0.437195
# 1662 -0.369025  -1.168422
# 1663  2.220060   1.702652
# 1664  0.409794   0.358453
# 1665 -0.579677  -0.671366
#
# [1666 rows x 2 columns]

# %% [markdown]
# # Part 2: Regression Problem for 'Price range'

# %%
# Price range is the target feature now.
x = df_new.drop('Price range',axis=1)
y = df_new['Price range']

# %%
#standardising features
sc= StandardScaler()
x = pd.DataFrame(sc.fit_transform(x), columns = x.columns)
x
# Out:
#           City  Longitude  Latitude  Cuisines  Average Cost for two  \
# 0    -3.717960   0.290958  0.106622  1.043113              0.949893
# 1    -3.717960  -3.963475 -3.741286  1.043113              0.645136
# 2    -3.717960   0.290962  0.106504  0.521909              0.138808
# 3    -3.717960   0.290225  0.111476  1.340944             -0.182290
# 4    -3.717960   0.290741  0.112298  0.694757              1.212326
# ...        ...        ...       ...       ...                   ...
# 8321  1.933352   0.582717 -1.224675 -0.499226              0.409794
# 8322  1.933352  -3.963475 -3.741286 -1.108184             -0.182290
# 8323  1.933352   0.580203 -1.231014 -1.403355              0.409794
# 8324  1.933352   0.581378 -1.230781 -1.722460              1.897367
# 8325  1.933352   0.580184 -1.230790 -0.020569              1.777669
#
#       Aggregate rating     Votes  Has Table booking_Yes  \
# 0             1.060167  1.006844              -0.350297
# ...

# %%
# checking multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.052453                     City
# 1       9.576171                Longitude
# 2       9.744391                 Latitude
# 3       1.023545                 Cuisines
# 4       1.848518     Average Cost for two
# 5      43.399861         Aggregate rating
# 6       5.294467                    Votes
# 7       1.475399    Has Table booking_Yes
# 8       1.258507  Has Online delivery_Yes
# 9            inf       Rating color_Green
# 10           inf      Rating color_Orange
# 11           inf         Rating color_Red
# 12           inf       Rating color_White
# 13           inf      Rating color_Yellow
# 14           inf    Rating text_Excellent
# 15           inf         Rating text_Good
# 16           inf    Rating text_Not rated
# 17           inf         Rating text_Poor
# 18           inf    Rating text_Very Good

# %%
x = x.drop(['Rating color_White','Rating text_Good','Rating text_Not rated'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.052453                     City
# 1       9.576171                Longitude
# 2       9.744391                 Latitude
# 3       1.023545                 Cuisines
# 4       1.848518     Average Cost for two
# 5      43.399861         Aggregate rating
# 6       5.294467                    Votes
# 7       1.475399    Has Table booking_Yes
# 8       1.258507  Has Online delivery_Yes
# 9            inf       Rating color_Green
# 10     37.205356      Rating color_Orange
# 11           inf         Rating color_Red
# 12     41.441129      Rating color_Yellow
# 13      5.716526    Rating text_Excellent
# 14           inf         Rating text_Poor
# 15           inf    Rating text_Very Good

# %%
x = x.drop(['Rating text_Very Good'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.052453                     City
# 1       9.576171                Longitude
# 2       9.744391                 Latitude
# 3       1.023545                 Cuisines
# 4       1.848518     Average Cost for two
# 5      43.399861         Aggregate rating
# 6       5.294467                    Votes
# 7       1.475399    Has Table booking_Yes
# 8       1.258507  Has Online delivery_Yes
# 9      23.101430       Rating color_Green
# 10     37.205356      Rating color_Orange
# 11           inf         Rating color_Red
# 12     41.441129      Rating color_Yellow
# 13      5.716526    Rating text_Excellent
# 14           inf         Rating text_Poor

# %%
x = x.drop(['Rating text_Poor'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.052453                     City
# 1       9.576171                Longitude
# 2       9.744391                 Latitude
# 3       1.023545                 Cuisines
# 4       1.848518     Average Cost for two
# 5      43.399861         Aggregate rating
# 6       5.294467                    Votes
# 7       1.475399    Has Table booking_Yes
# 8       1.258507  Has Online delivery_Yes
# 9      23.101430       Rating color_Green
# 10     37.205356      Rating color_Orange
# 11      2.573245         Rating color_Red
# 12     41.441129      Rating color_Yellow
# 13      5.716526    Rating text_Excellent

# %%
x = x.drop(['Aggregate rating'],axis = 1)

# %%
# Let's check if multicollinearity still exists
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features                 Features
# 0       1.050818                     City
# 1       9.573615                Longitude
# 2       9.734039                 Latitude
# 3       1.019503                 Cuisines
# 4       1.848178     Average Cost for two
# 5       5.044710                    Votes
# 6       1.475398    Has Table booking_Yes
# 7       1.254457  Has Online delivery_Yes
# 8       3.019682       Rating color_Green
# 9       3.634717      Rating color_Orange
# 10      1.373364         Rating color_Red
# 11      4.941990      Rating color_Yellow
# 12      1.403276    Rating text_Excellent

# %% [markdown]
# - This looks fine now!

# %%
# Removing skewness
from sklearn.preprocessing import power_transform
X=power_transform(x, method='yeo-johnson')
X
# Out:
# array([[-2.06294152,  0.40548405, -1.00138462, ..., -0.14780342,
#          1.95905205, -0.10095396],
#        [-2.06294152, -2.84508712, -2.55535419, ..., -0.14780342,
#          1.95905205, -0.10095396],
#        [-2.06294152,  0.40550814, -1.00191499, ..., -0.14780342,
#          1.95905205, -0.10095396],
#        ...,
#        [ 6.37418376,  3.13599318, -2.43627343, ..., -0.14780342,
#         -0.51045096, -0.10095396],
#        [ 6.37418376,  3.15040686, -2.43623518, ..., -0.14780342,
#          1.95905205, -0.10095396],
#        [ 6.37418376,  3.13576632, -2.43623664, ..., -0.14780342,
#         -0.51045096, -0.10095396]])

# %%
#checking for skewness is removed or not
skew_df=pd.DataFrame(X)
skew_df.skew()
# Out:
# 0     0.693326
# 1     2.581545
# 2     1.425181
# 3    -0.040039
# 4    -0.086485
# 5     0.019632
# 6     2.504879
# 7     0.963153
# 8     3.407144
# 9     0.256267
# 10    6.619132
# 11    1.448862
# 12    9.806319
# dtype: float64

# %% [markdown]
# - skewness is treated now.It cant be reduced furthermore.

# %%
# Importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Finding the best Random State
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.7288459011524406
# testing accuracy is  0.7339949164147934
#
#
# Random State is  1
# training accuracy is  0.729563452586697
# testing accuracy is  0.7306221178970935
#
#
# Random State is  2
# training accuracy is  0.7246628760544254
# testing accuracy is  0.749678340235516
#
#
# Random State is  3
# training accuracy is  0.7337576406939421
# testing accuracy is  0.7141268007640468
#
#
# Random State is  4
# training accuracy is  0.7319384613341144
# testing accuracy is  0.7217074099713143
#
#
# Random State is  5
# training accuracy is  0.7317723205202052
# testing accuracy is  0.7219362772385336
#
#
# Random State is  6
# training accuracy is  0.7315021434843916
# testing accuracy is  0.7238096770694942
#
#
# Random State is  7
# training accuracy is  0.727789779779882
# testing accuracy is  0.7382551183776551
#
#
# Random State is  8
# training accuracy is  0.7282860870579457
# testing accuracy is  0.7356609109085677
#
#
# ...

# %% [markdown]
# maximum r2 score is  0.7564400653840843 at random state  10

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=10)
print("shape of x_train is: ",x_train.shape)
print("shape of y_train is: ",y_train.shape)
print("shape of x_test is: ",x_test.shape)
print("shape of y_test is: ",y_test.shape)
# Out:
# shape of x_train is:  (6660, 13)
# shape of y_train is:  (6660,)
# shape of x_test is:  (1666, 13)
# shape of y_test is:  (1666,)

# %% [markdown]
# # 1. Linear Regression

# %%
lr.fit(x_train,y_train)
y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,y_train_pred))
print('testing accuracy is ', r2_score(y_test,y_test_pred))
print("Mean Squared Error is ",mean_squared_error(y_test,y_test_pred))
print("Mean Absolute Error is ",mean_absolute_error(y_test,y_test_pred))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred)))
# Out:
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# Mean Squared Error is  0.2532812916194745
# Mean Absolute Error is  0.4238943192006981
# Root Mean Squared Error is  0.5032705948289394

# %%
from sklearn.model_selection import cross_val_score
#cross validation of the lr model
for j in range(2,20):
    cv_score = cross_val_score(lr,x,y,cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,y_train_pred))
    print('testing accuracy is ', r2_score(y_test,y_test_pred))
# Out:
# At fold  2 Mean CV score is  0.4056525893457741
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  3 Mean CV score is  0.41824391155229507
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  4 Mean CV score is  0.4068272562613444
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  5 Mean CV score is  0.670003940072739
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  6 Mean CV score is  0.7142860312843157
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  7 Mean CV score is  0.7138118887929625
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  8 Mean CV score is  0.7113135828134628
# training accuracy is  0.7155238765918199
# testing accuracy is  0.7496258461044627
# At fold  9 Mean CV score is  0.7100595663200734
# ...

# %% [markdown]
# # 2. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
y_train_pred_dtr = dtr.predict(x_train)
y_test_pred_dtr = dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train, y_train_pred_dtr))
print('testing accuracy is ', r2_score(y_test, y_test_pred_dtr))
print('Mean squared error is ', mean_squared_error(y_test,y_test_pred_dtr))
print('Mean Absolute error is ', mean_absolute_error(y_test,y_test_pred_dtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred_dtr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.9838588187804405
# Mean squared error is  0.0163285992741079
# Mean Absolute error is  0.014055256590460726
# Root Mean Squared Error is  0.12778340766354565

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cv_dtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_dtr.mean())
# Out:
# At fold  2 Mean CV score is  0.9732685339640358
# At fold  3 Mean CV score is  0.9744069487636503
# At fold  4 Mean CV score is  0.9733359342460102
# At fold  5 Mean CV score is  0.9740376599063799
# At fold  6 Mean CV score is  0.9709472325190864
# At fold  7 Mean CV score is  0.9712712038874443
# At fold  8 Mean CV score is  0.9723105756639947
# At fold  9 Mean CV score is  0.9710009931787325

# %% [markdown]
# # 3. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)
y_train_pred_rfr = rfr.predict(x_train)
y_test_pred_rfr = rfr.predict(x_test)
print("training accuracy is ",r2_score(y_train,y_train_pred_rfr))
print("testing accuracy is ",r2_score(y_test,y_test_pred_rfr))
print("mean squared error is ",mean_squared_error(y_test, y_test_pred_rfr))
print("mean absolute error is ",mean_absolute_error(y_test, y_test_pred_rfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred_rfr)))
# Out:
# training accuracy is  0.9991362549409578
# testing accuracy is  0.9894723249614525
# mean squared error is  0.010649913699262688
# mean absolute error is  0.015210904981146002
# Root Mean Squared Error is  0.10319841907346589

# %%
# cross validation for random forest model

for j in range(2,10):
    cv_rfr = cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_rfr.mean())
# Out:
# At fold  2 Mean CV score is  0.9776438836805221
# At fold  3 Mean CV score is  0.9777586457815985
# At fold  4 Mean CV score is  0.9769011466557469
# At fold  5 Mean CV score is  0.9752348811796988
# At fold  6 Mean CV score is  0.9791177158223726
# At fold  7 Mean CV score is  0.9790874660969165
# At fold  8 Mean CV score is  0.9803072637089749
# At fold  9 Mean CV score is  0.9806750019497265

# %% [markdown]
# # 4.ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
y_train_pred_etr = etr.predict(x_train)
y_test_pred_etr = etr.predict(x_test)
print('training accuracy is ',r2_score(y_train, y_train_pred_etr))
print('testing accuracy is ',r2_score(y_test, y_test_pred_etr))
print('mean squared error is ',mean_squared_error(y_test, y_test_pred_etr))
print('mean absolute error is ',mean_absolute_error(y_test, y_test_pred_etr))
print('root mean squared error is ',np.sqrt(mean_squared_error(y_test, y_test_pred_etr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.9917349198687387
# mean squared error is  0.008361047410100218
# mean absolute error is  0.018621035429866255
# root mean squared error is  0.09143876317022348

# %%
# cross validation for extra trees regressor model

for j in range(2,10):
    cv_etr = cross_val_score(etr, x, y , cv = j)
    print('At fold ', j , "Mean CV score is ", cv_etr.mean())
# Out:
# At fold  2 Mean CV score is  0.9786308535813562
# At fold  3 Mean CV score is  0.977836774089006
# At fold  4 Mean CV score is  0.9778889051772801
# At fold  5 Mean CV score is  0.9817301287480816
# At fold  6 Mean CV score is  0.9834497776065718
# At fold  7 Mean CV score is  0.983803384805621
# At fold  8 Mean CV score is  0.982748472396958
# At fold  9 Mean CV score is  0.9822630563417749

# %% [markdown]
# # 5. GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
y_train_pred_gbr = gbr.predict(x_train)
y_test_pred_gbr = gbr.predict(x_test)
print('training accuracy is ',r2_score(y_train,y_train_pred_gbr))
print('testing accuracy is ',r2_score(y_test,y_test_pred_gbr))
print('mean squared error is ', mean_squared_error(y_test,y_test_pred_gbr))
print('mean absolute error is ', mean_absolute_error(y_test,y_test_pred_gbr))
print('root mean squared error is ', np.sqrt(mean_squared_error(y_test,y_test_pred_gbr)))
# Out:
# training accuracy is  0.9961583372911981
# testing accuracy is  0.9865648410642416
# mean squared error is  0.01359115689625689
# mean absolute error is  0.03052629939515379
# root mean squared error is  0.1165811172371276

# %%
# cross validation for gradient boosting regressor model

for j in range(2,10):
    cv_gbr = cross_val_score(gbr, x, y, cv=j)
    print('At fold ',j,'Mean cv score is ',cv_gbr.mean())
# Out:
# At fold  2 Mean cv score is  0.9767885976699482
# At fold  3 Mean cv score is  0.976490320147901
# At fold  4 Mean cv score is  0.97617986747779
# At fold  5 Mean cv score is  0.970821496323232
# At fold  6 Mean cv score is  0.9779392177539988
# At fold  7 Mean cv score is  0.9771155752208761
# At fold  8 Mean cv score is  0.9768577293075588
# At fold  9 Mean cv score is  0.977217381767166

# %% [markdown]
# ExtraTreesRegressor produces the best testing accuracy of 99.17% therefore using it as final model

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
parameter = {
    'n_estimators': [100,200,300,400,500],
        'max_features': ['sqrt','log2']
}

model = ExtraTreesRegressor()

rcv = RandomizedSearchCV(model,parameter,cv=9,n_jobs=-1).fit(x_train,y_train.values.ravel())

rcv.best_params_
# Out:
# {'n_estimators': 300, 'max_features': 'sqrt'}

# %%
# Checking score with best parameter
final_model=ExtraTreesRegressor(max_features='sqrt',n_estimators=300)
final_model.fit(x_train,y_train)
y_pred_test_final=final_model.predict(x_test)
print('Gradient Boosting Regressor = ',r2_score(y_test,y_pred_test_final))
# Out:
# Gradient Boosting Regressor =  0.9377617999804467

# %%
#saving the model
import joblib
joblib.dump(ExtraTreesRegressor(criterion='mse',max_features='sqrt',n_estimators=300), "Zomato case study_Part2.pkl")
# Out:
# ['Zomato case study_Part2.pkl']

# %%
# Conclusion
a=np.array(y_test)
predicted=np.array(y_pred_test_final)
df_con=pd.DataFrame({'Original':a,'Predicted':y_pred_test_final}, index=range(len(a)))
df_con
# Out:
#       Original  Predicted
# 0     0.777773   0.422449
# 1    -0.941537  -0.849841
# 2    -0.941537  -0.907151
# 3     1.463471   1.330943
# 4    -0.941537  -0.935806
# ...        ...        ...
# 1661 -0.941537  -0.855572
# 1662 -0.941537  -0.803992
# 1663 -0.941537  -0.889958
# 1664  0.777773   0.657421
# 1665  1.463471   1.477237
#
# [1666 rows x 2 columns]

# %% [markdown]
# # The End
