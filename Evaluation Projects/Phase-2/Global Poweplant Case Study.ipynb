# %% [markdown]
# # Project Description
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
# ## Key attributes of the database
# The database includes the following indicators:
#
# •	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
# •	`country_long` (text): longer form of the country designation
# •	`name` (text): name or title of the power plant, generally in Romanized form
# •	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
# •	`capacity_mw` (number): electrical generating capacity in megawatts
# •	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# •	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# •	`primary_fuel` (text): energy source used in primary electricity generation or export
# •	`other_fuel1` (text): energy source used in electricity generation or export
# •	`other_fuel2` (text): energy source used in electricity generation or export
# •	`other_fuel3` (text): energy source used in electricity generation or export
# •	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
# •	`owner` (text): majority shareholder of the power plant, generally in Romanized form
# •	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
# •	`url` (text): web document corresponding to the `source` field
# •	`geolocation_source` (text): attribution for geolocation information
# •	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# •	`year_of_capacity_data` (number): year the capacity information was reported
# •	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
# •	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
# •	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
# •	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
# •	`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
# •	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
# •	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
# •	`generation_data_source` (text): attribution for the reported generation information
# •	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
# •	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
# •	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
# •	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
# •	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
# •	'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
# •	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
# •	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
# •	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
# •	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017
# Fuel Type Aggregation
# We define the "Fuel Type" attribute of our database based on common fuel categories.
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw
#
# ## Dataset Link-
# •	https://github.com/wri/global-power-plant-database/blob/master/source_databases_csv/database_IND.csv

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading dataset

# %%
df= pd.read_csv("C:\\Users\\suven\\OneDrive\\Desktop\\Internship\\Evaluation Projects\\Second Phase\\Global Powerplant Case Study\\database_IND.csv")
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
# Checking rows and columns in dataset
df.shape
# Out:
# (907, 27)

# %% [markdown]
# - There are 907 rows and 27 columns in the dataset

# %%
# Seeing column names in one glance
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
# seeing the datatypes of columns
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# - There are 12 columns with object datatype
# - There are 15 columns with float64 datatype
# - The datatypes match the content filled in each of the columns

# %%
# Checking more info about the datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# - There are some columns which have missing/null values
# - There are 12 columns with object datatype and 15 columns with float64 datatype
# - country, country_long, name, gppd_idnr, url, owner, wepp_id columns can be removed as they are not useful for making prediction

# %%
# Checking unique values
df.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %%
# Checking null values
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# #### Observations:
#
# - There are 46 null values in latitude and longtitude columns
# - There are 709 null values in other_fuel1 column ---> can be dropped as majority of the values are missing
# - There are 906 null values in other_fuel2 column ---> can be dropped as majority of the values are missing
# - There are 907 null values in other_fuel3 column ---> can be dropped as all the values are missing
# - There are 380 null values in commissioning_year column
# - There are 565 null values in owner column
# - There are 19 null values in geolocation_source column
# - There are 907 null values in wepp_id column
# - There are 388 null values in year_of_capacity_data column
# - There are 907 null values in generation_gwh_2013 column---> can be dropped as all the values are missing
# - There are 509 null values in generation_gwh_2014 column
# - There are 485 null values in generation_gwh_2015 column
# - There are 473 null values in generation_gwh_2016 column
# - There are 467 null values in generation_gwh_2017 column
# - There are 459 null values in generation_gwh_2018 column
# - There are 907 null values in generation_gwh_2019 column ---> can be dropped as all the values are missing
# - There are 458 null values in generation_data_source column ---> can be dropped as it is the same value so iirelevant
# - There are 907 null values in estimated_generation_gwh column ---> can be dropped as all the values are missing
# - Rest of the columns have no missing/null values
#
#
# #### The above columns with null value will be dealt with later

# %%
# Checking the skewness of the dataset
df.skew()
# Out:
# capacity_mw                 3.123576
# latitude                   -0.145866
# longitude                   1.112646
# other_fuel3                      NaN
# commissioning_year         -1.067949
# wepp_id                          NaN
# year_of_capacity_data       0.000000
# generation_gwh_2013              NaN
# generation_gwh_2014         3.342707
# generation_gwh_2015         3.665904
# generation_gwh_2016         3.512370
# generation_gwh_2017         3.566070
# generation_gwh_2018         3.476298
# generation_gwh_2019              NaN
# estimated_generation_gwh         NaN
# dtype: float64

# %% [markdown]
# - We can see some columns possessing skewness. This will be dealt later.

# %%
# Checking the statistical summary of the dataset
df.describe().T
# Out:
#                           count         mean          std        min  \
# capacity_mw               907.0   326.223755   590.085456     0.0000
# latitude                  861.0    21.197918     6.239612     8.1689
# longitude                 861.0    77.464907     4.939316    68.6447
# other_fuel3                 0.0          NaN          NaN        NaN
# commissioning_year        527.0  1997.091082    17.082868  1927.0000
# wepp_id                     0.0          NaN          NaN        NaN
# year_of_capacity_data     519.0  2019.000000     0.000000  2019.0000
# generation_gwh_2013         0.0          NaN          NaN        NaN
# generation_gwh_2014       398.0  2431.823590  4026.440035     0.0000
# generation_gwh_2015       422.0  2428.226946  4194.596959     0.0000
# generation_gwh_2016       434.0  2467.936859  4162.884308     0.0000
# generation_gwh_2017       440.0  2547.759305  4196.991169     0.0000
# generation_gwh_2018       448.0  2600.804099  4314.880456     0.0000
# ...

# %% [markdown]
# - capacity_mw id positively skewed as mean is greater than median
# - generation_gwh_2014-2018 columns are positively skewed as mean is greater than median

# %% [markdown]
# # Data Visualization

# %%
# Plotting capacity_mw column (regression) 
sns.histplot(x= 'capacity_mw',kde = True, data=df)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Count'>

# %% [markdown]
# - capacity_mw is positively skewed

# %%
# Seeing countplot of primary_fuel
print("The count of each category of primary fuel columns are:\n", df['primary_fuel'].value_counts())

sns.countplot(x= 'primary_fuel', data=df)
# Out:
# The count of each category of primary fuel columns are:
#  Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# - In India, max fuel used by powerplants is coal followed by HydroFuel, then Solar, then wind and the rest

# %%
# Plotting commissioning_year in count plot
plt.figure(figsize=(20,5))
sns.countplot(x='commissioning_year', data=df)
plt.xticks(rotation =90)
df['commissioning_year'].value_counts()
# Out:
# 2015.0    28
# 2013.0    25
# 2012.0    23
# 2016.0    19
# 2010.0    18
#           ..
# 1946.0     1
# 1956.0     1
# 1937.0     1
# 1949.0     1
# 1953.0     1
# Name: commissioning_year, Length: 73, dtype: int64

# %% [markdown]
# - No of powerplants increases with passing commisioning_year

# %%
# Plotting generation_gwh_2014
sns.histplot(x= 'generation_gwh_2014',kde = True, data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='Count'>

# %% [markdown]
# - generation_gwh_2014 is positively skewed

# %%
# Plotting generation_gwh_2015
sns.histplot(x= 'generation_gwh_2015',kde = True, data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='Count'>

# %% [markdown]
# - generation_gwh_2015 is positively skewed

# %%
# Plotting generation_gwh_2016
sns.histplot(x= 'generation_gwh_2016',kde = True, data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='Count'>

# %% [markdown]
# - generation_gwh_2016 is positively skewed

# %%
# Plotting generation_gwh_2017
sns.histplot(x= 'generation_gwh_2017',kde = True, data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='Count'>

# %% [markdown]
# - generation_gwh_2017 is positively skewed

# %%
# Checking for outliers
plt.figure(figsize=(20,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - capacity_mw has outliers
# - generation_gwh_2014 to 2018 have outliers
# - We will treat them later

# %% [markdown]
# # Data Pre-processing

# %%
# dropping the columns as mentioned above

df.drop(['country', 'country_long', 'name', 'gppd_idnr','other_fuel1','other_fuel2','other_fuel3','owner', 'url','wepp_id','generation_gwh_2013','generation_gwh_2019' ,'generation_data_source'], axis=1, inplace=True)
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0          2.5   28.1839    73.2407        Solar              2011.0
# 1         98.0   24.7663    74.6090         Coal                 NaN
# 2         39.2   21.9038    69.3732         Wind                 NaN
# 3        135.0   23.8712    91.3602          Gas              2004.0
# 4       1800.0   21.9603    82.4091         Coal              2015.0
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
df.drop('estimated_generation_gwh',axis=1,inplace=True)
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0          2.5   28.1839    73.2407        Solar              2011.0
# 1         98.0   24.7663    74.6090         Coal                 NaN
# 2         39.2   21.9038    69.3732         Wind                 NaN
# 3        135.0   23.8712    91.3602          Gas              2004.0
# 4       1800.0   21.9603    82.4091         Coal              2015.0
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
print(df.shape)
# Out:
# (907, 13)

# %% [markdown]
# ### Dealing with the null/missing values

# %%
df.isna().sum()
# Out:
# capacity_mw                0
# latitude                  46
# longitude                 46
# primary_fuel               0
# commissioning_year       380
# source                     0
# geolocation_source        19
# year_of_capacity_data    388
# generation_gwh_2014      509
# generation_gwh_2015      485
# generation_gwh_2016      473
# generation_gwh_2017      467
# generation_gwh_2018      459
# dtype: int64

# %%
# 1. latitude column: Imputing missing values with mode
df['latitude'] = df['latitude'].fillna(df['latitude'].mode()[0])

# 2. commissioning_year  column: Imputing missing values with mode
df['commissioning_year'] = df['commissioning_year'].fillna(df['commissioning_year'].mode()[0])

# 3. geolocation_source column: Imputing missing values with mode
df['geolocation_source'] = df['geolocation_source'].fillna(df['geolocation_source'].mode()[0])

# 4. year_of_capacity_data   column: Imputing missing values with mode
df['year_of_capacity_data'] = df['year_of_capacity_data'].fillna(df['year_of_capacity_data'].mode()[0])

# 5. Imputing generation_gwh_2014 by mean
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna(df['generation_gwh_2014'].mean())

# 6.Imputing generation_gwh_2015 by mean
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna(df['generation_gwh_2015'].mean())

# 7. Imputing generation_gwh_2016 by mean
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna(df['generation_gwh_2016'].mean())

# 8. Imputing generation_gwh_2017 by mean
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna(df['generation_gwh_2017'].mean())

# 9. Imputing generation_gwh_2018 by mean
df['generation_gwh_2018']=df['generation_gwh_2018'].fillna(df['generation_gwh_2018'].mean())

#10. longitude column: Imputing missing values with mode
df['longitude'] = df['longitude'].fillna(df['longitude'].mode()[0])

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal              2015.0
# 2           39.2   21.9038    69.3732         Wind              2015.0
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar              2015.0
# 904         25.5   15.2758    75.5811         Wind              2015.0
# 905         80.0   24.3500    73.7477         Coal              2015.0
# 906         16.5    9.9344    77.4768         Wind              2015.0
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %%
# Checking for Null values after imuptation
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year       0
# source                   0
# geolocation_source       0
# year_of_capacity_data    0
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# dtype: int64

# %% [markdown]
# - No null values in the dataset now

# %% [markdown]
# ### Encoding the categorical columns

# %%
# checking datatype of columns
df.dtypes
# Out:
# capacity_mw              float64
# latitude                 float64
# longitude                float64
# primary_fuel              object
# commissioning_year       float64
# source                    object
# geolocation_source        object
# year_of_capacity_data    float64
# generation_gwh_2014      float64
# generation_gwh_2015      float64
# generation_gwh_2016      float64
# generation_gwh_2017      float64
# generation_gwh_2018      float64
# dtype: object

# %% [markdown]
# - There are three columns; primary_fuel ,source and geolocation_source having object datatype

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['primary_fuel']= le.fit_transform(df['primary_fuel'])
df['source']= le.fit_transform(df['source'])
df['geolocation_source']= le.fit_transform(df['geolocation_source'])
df
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2015.0
# 2           39.2   21.9038    69.3732             7              2015.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2015.0
# 904         25.5   15.2758    75.5811             7              2015.0
# 905         80.0   24.3500    73.7477             1              2015.0
# 906         16.5    9.9344    77.4768             7              2015.0
#
#      source  geolocation_source  year_of_capacity_data  generation_gwh_2014  \
# ...

# %%
df.dtypes
# Out:
# capacity_mw              float64
# latitude                 float64
# longitude                float64
# primary_fuel               int32
# commissioning_year       float64
# source                     int32
# geolocation_source         int32
# year_of_capacity_data    float64
# generation_gwh_2014      float64
# generation_gwh_2015      float64
# generation_gwh_2016      float64
# generation_gwh_2017      float64
# generation_gwh_2018      float64
# dtype: object

# %% [markdown]
# - The categorical columns have been converted to numeric datatype

# %% [markdown]
# ### Dealing with Outliers

# %%
# Importing Zscore
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (907, 13)

# %%
# Setting threshold at 3 and detecting the outliers
print(np.where(z>3)) # these are all the outliers in the data
# Out:
# (array([ 15,  15,  15,  15,  15,  71,  80, 143, 143, 143, 143, 143, 143,
#        147, 158, 179, 183, 191, 209, 209, 209, 209, 209, 209, 222, 244,
#        299, 308, 308, 308, 308, 308, 308, 321, 323, 333, 340, 342, 345,
#        360, 363, 364, 364, 364, 364, 364, 364, 371, 375, 416, 427, 444,
#        454, 478, 482, 484, 493, 493, 493, 493, 493, 493, 494, 494, 494,
#        494, 494, 494, 499, 519, 538, 541, 573, 577, 583, 601, 621, 638,
#        648, 648, 648, 648, 648, 648, 657, 657, 657, 657, 657, 657, 661,
#        669, 689, 695, 695, 695, 695, 695, 695, 706, 709, 721, 721, 721,
#        721, 724, 724, 724, 724, 724, 726, 726, 726, 726, 726, 726, 728,
#        767, 786, 786, 786, 786, 786, 786, 788, 807, 808, 808, 808, 808,
#        808, 808, 818, 832, 848, 870, 871, 879, 880, 880, 880, 880, 880,
#        880, 895, 900], dtype=int64), array([ 0,  9, 10, 11, 12,  5,  5,  0,  8,  9, 10, 11, 12,  0,  8,  2,  2,
# ...

# %%
# Removing the outlier 
df1=df[(z<3).all(axis=1)]
print("shape of new dataset excluding outliers is: ",df1.shape)
# Out:
# shape of new dataset excluding outliers is:  (0, 13)

# %% [markdown]
# - Since the whole data is showing in the outliers , therefore I will not remove/treat the outliers fearing the loss of data

# %% [markdown]
# # Part 1: Regression model for the Prediction of 'capacity_mw'

# %%
# Splitting data into inputs and output variable
x = df.drop(['capacity_mw'], axis=1)
y= df['capacity_mw']
print(" shape of x is", x.shape)
print(" shape of y is", y.shape)
# Out:
#  shape of x is (907, 12)
#  shape of y is (907,)

# %%
# Dealing with skewness
from sklearn.preprocessing import power_transform
x=power_transform(x, method='yeo-johnson')
x
# Out:
# array([[ 1.16782905, -0.82677812,  1.1713128 , ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.60087083, -0.43172096, -0.99629108, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.12841314, -2.23126627,  1.4415761 , ...,  0.31578736,
#          0.31292509,  0.32193752],
#        ...,
#        [-0.95543806, -0.17730207,  1.4415761 , ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.53201699, -0.67505608, -0.99629108, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [-1.81556656,  0.26406668,  1.4415761 , ...,  0.31578736,
#          0.31292509,  0.32193752]])

# %%
#checking for skewness is removed or not
skew_df=pd.DataFrame(x)
skew_df.skew()
# Out:
# 0    -0.069526
# 1     0.040507
# 2    -0.047067
# 3    -1.077695
# 4    -0.214066
# 5    -2.132728
# 6     0.000000
# 7     0.123226
# 8     0.074582
# 9     0.041821
# 10    0.018337
# 11    0.000783
# dtype: float64

# %% [markdown]
# - proceeding further as skewness cant be reduced furthermore

# %%
# Standardizing the data

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x = ss.fit_transform(x)
x
# Out:
# array([[ 1.16782905, -0.82677572,  1.1713128 , ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.60087083, -0.43171855, -0.99629108, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.12841314, -2.23126386,  1.4415761 , ...,  0.31578736,
#          0.31292509,  0.32193752],
#        ...,
#        [-0.95543806, -0.17729966,  1.4415761 , ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.53201699, -0.67505367, -0.99629108, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [-1.81556656,  0.26406909,  1.4415761 , ...,  0.31578736,
#          0.31292509,  0.32193752]])

# %%
# Importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Finding the best Random State
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.44646663706862844
# testing accuracy is  0.5381781196155929
#
#
# Random State is  1
# training accuracy is  0.48386954330274123
# testing accuracy is  0.4091232894076485
#
#
# Random State is  2
# training accuracy is  0.47115115578876576
# testing accuracy is  0.4845665176260485
#
#
# Random State is  3
# training accuracy is  0.4646722066940312
# testing accuracy is  0.5031102803193397
#
#
# Random State is  4
# training accuracy is  0.4701535543589618
# testing accuracy is  0.48228640926982136
#
#
# Random State is  5
# training accuracy is  0.46866339317752437
# testing accuracy is  0.48341818226080724
#
#
# Random State is  6
# training accuracy is  0.4810958112849968
# testing accuracy is  0.4414406355373759
#
#
# Random State is  7
# training accuracy is  0.5009952912256094
# testing accuracy is  0.33069274496236345
#
#
# Random State is  8
# training accuracy is  0.4607291224269433
# testing accuracy is  0.5393793716069998
#
#
# ...

# %%
We have got the best random state as 61 where the testing accuracy is 0.59 and training is 0.42

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=61)
print("shape of x_train is: ",x_train.shape)
print("shape of y_train is: ",y_train.shape)
print("shape of x_test is: ",x_test.shape)
print("shape of y_test is: ",y_test.shape)
# Out:
# shape of x_train is:  (725, 12)
# shape of y_train is:  (725,)
# shape of x_test is:  (182, 12)
# shape of y_test is:  (182,)

# %% [markdown]
# # 1. Linear Regression

# %%
lr.fit(x_train,y_train)
y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,y_train_pred))
print('testing accuracy is ', r2_score(y_test,y_test_pred))
print("Mean Squared Error is ",mean_squared_error(y_test,y_test_pred))
print("Mean Absolute Error is ",mean_absolute_error(y_test,y_test_pred))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred)))
# Out:
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# Mean Squared Error is  179074.31915970345
# Mean Absolute Error is  288.7357495324116
# Root Mean Squared Error is  423.17173719390036

# %%
from sklearn.model_selection import cross_val_score
#cross validation of the lr model
for j in range(2,20):
    cv_score = cross_val_score(lr,x,y,cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,y_train_pred))
    print('testing accuracy is ', r2_score(y_test,y_test_pred))
# Out:
# At fold  2 Mean CV score is  0.3613652619536882
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# At fold  3 Mean CV score is  0.3886573944038673
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# At fold  4 Mean CV score is  0.40405828505396535
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# At fold  5 Mean CV score is  0.4121448509780522
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# At fold  6 Mean CV score is  0.39158006702429055
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# At fold  7 Mean CV score is  0.4111416156624159
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# At fold  8 Mean CV score is  0.4168595756776429
# training accuracy is  0.42595760043948305
# testing accuracy is  0.5961003701912795
# ...

# %% [markdown]
# # 2. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
y_train_pred_dtr = dtr.predict(x_train)
y_test_pred_dtr = dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train, y_train_pred_dtr))
print('testing accuracy is ', r2_score(y_test, y_test_pred_dtr))
print('Mean squared error is ', mean_squared_error(y_test,y_test_pred_dtr))
print('Mean Absolute error is ', mean_absolute_error(y_test,y_test_pred_dtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred_dtr)))
# Out:
# training accuracy is  0.9999323857145621
# testing accuracy is  0.7647798814493139
# Mean squared error is  104287.99502014148
# Mean Absolute error is  156.7985576923077
# Root Mean Squared Error is  322.9365185607559

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cv_dtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_dtr.mean())
# Out:
# At fold  2 Mean CV score is  0.7147232754111539
# At fold  3 Mean CV score is  0.749548492960138
# At fold  4 Mean CV score is  0.7275156326016667
# At fold  5 Mean CV score is  0.7439809006345762
# At fold  6 Mean CV score is  0.7259809572259673
# At fold  7 Mean CV score is  0.7475333617952479
# At fold  8 Mean CV score is  0.7612214177586456
# At fold  9 Mean CV score is  0.7232083450873233

# %% [markdown]
# # 3. RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)
y_train_pred_rfr = rfr.predict(x_train)
y_test_pred_rfr = rfr.predict(x_test)
print("training accuracy is ",r2_score(y_train,y_train_pred_rfr))
print("testing accuracy is ",r2_score(y_test,y_test_pred_rfr))
print("mean squared error is ",mean_squared_error(y_test, y_test_pred_rfr))
print("mean absolute error is ",mean_absolute_error(y_test, y_test_pred_rfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_test_pred_rfr)))
# Out:
# training accuracy is  0.9783971040661947
# testing accuracy is  0.8986092613268405
# mean squared error is  44952.94414009247
# mean absolute error is  113.70650578033703
# Root Mean Squared Error is  212.02109362064064

# %%
# cross validation for random forest model

for j in range(2,10):
    cv_rfr = cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_rfr.mean())
# Out:
# At fold  2 Mean CV score is  0.8117131328622461
# At fold  3 Mean CV score is  0.856920429131726
# At fold  4 Mean CV score is  0.8492078159644745
# At fold  5 Mean CV score is  0.851429584543
# At fold  6 Mean CV score is  0.850360340095076
# At fold  7 Mean CV score is  0.8541314729470716
# At fold  8 Mean CV score is  0.8560863557811607
# At fold  9 Mean CV score is  0.8426726883416955

# %% [markdown]
# # 4. ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
y_train_pred_etr = etr.predict(x_train)
y_test_pred_etr = etr.predict(x_test)
print('training accuracy is ',r2_score(y_train, y_train_pred_etr))
print('testing accuracy is ',r2_score(y_test, y_test_pred_etr))
print('mean squared error is ',mean_squared_error(y_test, y_test_pred_etr))
print('mean absolute error is ',mean_absolute_error(y_test, y_test_pred_etr))
print('root mean squared error is ',np.sqrt(mean_squared_error(y_test, y_test_pred_etr)))
# Out:
# training accuracy is  0.9999323832411556
# testing accuracy is  0.9118136303753595
# mean squared error is  39098.6099867861
# mean absolute error is  106.21148583333334
# root mean squared error is  197.73368450212547

# %%
# cross validation for extra trees regressor model

for j in range(2,10):
    cv_etr = cross_val_score(etr, x, y , cv = j)
    print('At fold ', j , "Mean CV score is ", cv_etr.mean())
# Out:
# At fold  2 Mean CV score is  0.8357486274191459
# At fold  3 Mean CV score is  0.870853040986525
# At fold  4 Mean CV score is  0.8627060790443959
# At fold  5 Mean CV score is  0.8612445620610114
# At fold  6 Mean CV score is  0.8723724629900446
# At fold  7 Mean CV score is  0.8685540395156129
# At fold  8 Mean CV score is  0.8686902473936529
# At fold  9 Mean CV score is  0.865453038481653

# %% [markdown]
# # 5. Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
y_train_pred_gbr = gbr.predict(x_train)
y_test_pred_gbr = gbr.predict(x_test)
print('training accuracy is ',r2_score(y_train,y_train_pred_gbr))
print('testing accuracy is ',r2_score(y_test,y_test_pred_gbr))
print('mean squared error is ', mean_squared_error(y_test,y_test_pred_gbr))
print('mean absolute error is ', mean_absolute_error(y_test,y_test_pred_gbr))
print('root mean squared error is ', np.sqrt(mean_squared_error(y_test,y_test_pred_gbr)))
# Out:
# training accuracy is  0.966972538257845
# testing accuracy is  0.8942797479193931
# mean squared error is  46872.491989390124
# mean absolute error is  113.42503450338212
# root mean squared error is  216.50055886623048

# %%
# cross validation for gradient boosting regressor model

for j in range(2,10):
    cv_gbr = cross_val_score(gbr, x, y, cv=j)
    print('At fold ',j,'Mean cv score is ',cv_gbr.mean())
# Out:
# At fold  2 Mean cv score is  0.8060669995556089
# At fold  3 Mean cv score is  0.8343638954433691
# At fold  4 Mean cv score is  0.8346890735268657
# At fold  5 Mean cv score is  0.8380723640936143
# At fold  6 Mean cv score is  0.8335298329248518
# At fold  7 Mean cv score is  0.8259881722219905
# At fold  8 Mean cv score is  0.8297003042227378
# At fold  9 Mean cv score is  0.8190362560802577

# %% [markdown]
# - Out of the above 5 models, RandomForestRegressor, ExtraTreesRegressor and GradientBoostingRegressor produce the best testing accuracy score ; 90%, 91% ,89% respectively showing
# - cross val score at fold 5 for the rfr,etr and gbr models are ;85%, 86% and 84% respectively showing that these models are performing well.

# %% [markdown]
# ## Regularizing techniques

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV

# %%
# Doing Lasso Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'tol': [0.001,0.0001,0.00001,0.000001]}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'max_iter': 100, 'random_state': 0, 'tol': 0.001}

# %%
ls=Lasso(alpha=10, max_iter=100, random_state=0, tol=0.001)
ls.fit(x_train,y_train)
y_pred_train_ls=ls.predict(x_train)
y_pred_test_ls=ls.predict(x_test)
print('training accuracy is ', r2_score(y_train,y_pred_train_ls))
print('testing accuracy is ', r2_score(y_test,y_pred_test_ls))
print("Mean Squared Error is ",mean_squared_error(y_test,y_pred_test_ls))
print("Mean Absolute Error is ",mean_absolute_error(y_test,y_pred_test_ls))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_pred_test_ls)))
# Out:
# training accuracy is  0.4241768197033786
# testing accuracy is  0.5789796048604405
# Mean Squared Error is  186665.04014294618
# Mean Absolute Error is  290.1886220767744
# Root Mean Squared Error is  432.0474975543154

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_ls=cross_val_score(ls, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_ls.mean())
# Out:
# At fold  2 Mean CV score is  0.3700927259310771
# At fold  3 Mean CV score is  0.39387715123252076
# At fold  4 Mean CV score is  0.4127717739120655
# At fold  5 Mean CV score is  0.41841428429099264
# At fold  6 Mean CV score is  0.39810800161016563
# At fold  7 Mean CV score is  0.4155593958838221
# At fold  8 Mean CV score is  0.4222824007547523
# At fold  9 Mean CV score is  0.39136268859717566

# %%
# Doing Ridge Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']}

rg=Ridge()
clf=GridSearchCV(rg,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 100, 'max_iter': 10, 'random_state': 7, 'solver': 'sag'}

# %%
rg=Ridge(alpha=100, max_iter=10, random_state=7, solver='sag')
rg.fit(x_train,y_train)
y_pred_train_rg= rg.predict(x_train)
y_pred_test_rg= rg.predict(x_test)
print('training accuracy is ', r2_score(y_train,y_pred_train_rg))
print('testing accuracy is ', r2_score(y_test,y_pred_test_rg))
print("Mean Squared Error is ",mean_squared_error(y_test,y_pred_test_rg))
print("Mean Absolute Error is ",mean_absolute_error(y_test,y_pred_test_rg))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,y_pred_test_rg)))
# Out:
# training accuracy is  0.42178947524730626
# testing accuracy is  0.580702254579092
# Mean Squared Error is  185901.280280962
# Mean Absolute Error is  290.93837508106975
# Root Mean Squared Error is  431.1627074330084

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_rg=cross_val_score(rg, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_rg.mean())
# Out:
# At fold  2 Mean CV score is  0.380930371208561
# At fold  3 Mean CV score is  0.4028716297104568
# At fold  4 Mean CV score is  0.4180679672615654
# At fold  5 Mean CV score is  0.42455807569034
# At fold  6 Mean CV score is  0.40411231222673255
# At fold  7 Mean CV score is  0.42238100524771466
# At fold  8 Mean CV score is  0.4252030451157228
# At fold  9 Mean CV score is  0.3957987096297782

# %% [markdown]
# Lasso and ridge not performing well as the Accuracy is less than above models
#
# Hence selecting the Extra Tree Classifier for the data

# %% [markdown]
# ## Hyperparameter Tunning

# %%
# modelling with ExtraTreesRegressor

parameter = {
    'n_estimators': [100,200,300,400,500],
        'max_features': ['sqrt','log2'],
      'criterion':['mse','mae']
}

model = ExtraTreesRegressor ()

gcv = GridSearchCV(model,parameter,cv=9,n_jobs=-1).fit(x_train,y_train.values.ravel())

gcv.best_params_
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt', 'n_estimators': 300}

# %%
# Checking score with best parameter
final_model=ExtraTreesRegressor(criterion='mse',max_features='sqrt',n_estimators=300)
final_model.fit(x_train,y_train)
y_pred_test_final=final_model.predict(x_test)
print('Final Accuracy is with Random Forest Classifier = ',r2_score(y_test,y_pred_test_final))
# Out:
# Final Accuracy is with Random Forest Classifier =  0.9117454833353607

# %%
#Importing Job lib for saving the model
import joblib
joblib.dump(ExtraTreesRegressor(criterion='mse',max_features='sqrt',n_estimators=300), "Power Plant Capacity Prediction.pkl")
# Out:
# ['Power Plant Capacity Prediction.pkl']

# %%
# Conclusion
a=np.array(y_test)
predicted=np.array(y_pred_test_final)
df_con=pd.DataFrame({'Original':a,'Predicted':y_pred_test_final}, index=range(len(a)))
df_con
# Out:
#      Original   Predicted
# 0       132.0  149.106717
# 1        90.0   95.070033
# 2        11.2   13.023333
# 3       120.0   54.166667
# 4       210.0  352.898500
# ..        ...         ...
# 177     300.0  538.753667
# 178      42.0   37.019667
# 179     920.0  772.509633
# 180      17.0   31.186400
# 181     100.0   70.449667
#
# [182 rows x 2 columns]

# %% [markdown]
# # Part 2: Classification model for the Prediction of 'Primary fuel type'

# %% [markdown]
# ## Splitting features and target variable from the dataset

# %%
X = df.drop(['primary_fuel'], axis=1)
Y= df['primary_fuel']
print(X.shape)
print(Y.shape)
# Out:
# (907, 12)
# (907,)

# %%
# Removing skewness
from sklearn.preprocessing import power_transform
X=power_transform(X, method='yeo-johnson')
X
# Out:
# array([[-1.69576688,  1.16782905, -0.82677812, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.19369368,  0.60087083, -0.43172096, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [-0.2923371 ,  0.12841314, -2.23126627, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        ...,
#        [-0.52277344, -0.95543806, -0.17730207, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.08691496,  0.53201699, -0.67505608, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [-0.75589054, -1.81556656,  0.26406668, ...,  0.31578736,
#          0.31292509,  0.32193752]])

# %%
#checking for skewness is removed or not
skew_df=pd.DataFrame(X)
skew_df.skew()
# Out:
# 0     0.022164
# 1    -0.069526
# 2     0.040507
# 3    -1.077695
# 4    -0.214066
# 5    -2.132728
# 6     0.000000
# 7     0.123226
# 8     0.074582
# 9     0.041821
# 10    0.018337
# 11    0.000783
# dtype: float64

# %% [markdown]
# - We cannot further reduce the skewness as it is very large skewness is present in the dataset

# %%
# Importing StandardScaler
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = ss.fit_transform(X)
X
# Out:
# array([[-1.69576688,  1.16782905, -0.82677572, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.19369368,  0.60087083, -0.43171855, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [-0.2923371 ,  0.12841314, -2.23126386, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        ...,
#        [-0.52277344, -0.95543806, -0.17729966, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [ 0.08691496,  0.53201699, -0.67505367, ...,  0.31578736,
#          0.31292509,  0.32193752],
#        [-0.75589054, -1.81556656,  0.26406909, ...,  0.31578736,
#          0.31292509,  0.32193752]])

# %%
# Checkin value_counts of target variable
Y.value_counts()
# Out:
# 1    258
# 3    251
# 6    127
# 7    123
# 2     69
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# - This  looks like an imbalanced class so we will deal with it now using SMOTE

# %%
# Importing Libraries for it 
from imblearn.over_sampling import SMOTE
sm=SMOTE()
X,Y=sm.fit_resample(X,Y)
Y.value_counts()
# Out:
# 6    258
# 1    258
# 7    258
# 2    258
# 3    258
# 0    258
# 5    258
# 4    258
# Name: primary_fuel, dtype: int64

# %% [markdown]
# - The class looks balanced now

# %% [markdown]
# ## Modelling the data

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
lg=LogisticRegression()

# %%
# Finding the random state
maxaccu=0
maxrs=0
for i in range(1,100):
    print("At Random State ", i)
    Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=.20, random_state=i)
    lg.fit(Xtrain,Ytrain)
    predlg=lg.predict(Xtest)
    trainlg=lg.predict(Xtrain)
    acc=accuracy_score(Ytest,predlg)
    accu=accuracy_score(Ytrain,trainlg)
    print('testing accuracy', acc, 'randon state',i)
    print('Training Accuracy', accu, 'random state', i)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
        print('max accuracy', maxaccu , 'max_random_state', i)
# Out:
# At Random State  1
# testing accuracy 0.7627118644067796 randon state 1
# Training Accuracy 0.7837674136886735 random state 1
# max accuracy 0.7627118644067796 max_random_state 1
# At Random State  2
# testing accuracy 0.7602905569007264 randon state 2
# Training Accuracy 0.7849788007268322 random state 2
# At Random State  3
# testing accuracy 0.7675544794188862 randon state 3
# Training Accuracy 0.7837674136886735 random state 3
# max accuracy 0.7675544794188862 max_random_state 3
# At Random State  4
# testing accuracy 0.7699757869249395 randon state 4
# Training Accuracy 0.788007268322229 random state 4
# max accuracy 0.7699757869249395 max_random_state 4
# At Random State  5
# testing accuracy 0.7481840193704601 randon state 5
# Training Accuracy 0.7910357359176257 random state 5
# At Random State  6
# testing accuracy 0.7651331719128329 randon state 6
# Training Accuracy 0.7946698970321018 random state 6
# At Random State  7
# testing accuracy 0.8038740920096852 randon state 7
# ...

# %%
# Checking for the Max. Accuracy at Random State
print('max accuracy', maxaccu , 'max_random_state', i)
# Out:
# max accuracy 0.8111380145278451 max_random_state 99

# %%
# train test split for the data with suggested random state
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.20,random_state=99)

# %% [markdown]
# # 1. Logistic Regression

# %%
# Checking score again for the the lr model 
lg=LogisticRegression()
lg.fit(X_train,Y_train)
Y_pred_test_lg = lg.predict(X_test)
Y_pred_train_lg = lg.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,Y_pred_train_lg))
print("Testing accuracy is ",accuracy_score(Y_test,Y_pred_test_lg))
print(confusion_matrix(Y_test,Y_pred_test_lg))
print(classification_report(Y_test,Y_pred_test_lg))
# Out:
# Training accuracy is  0.7861901877649909
# Testing accuracy is  0.774818401937046
# [[45  0  0  0  0  0  0  8]
#  [ 2 27  4  1 10  0  0  3]
#  [ 3  4 19 10  5  7  0  0]
#  [ 0  3  9 36  5  2  0  1]
#  [ 0  0  0  2 48  0  0  0]
#  [ 0  3  1  4  0 47  0  2]
#  [ 0  0  0  0  0  3 48  0]
#  [ 0  1  0  0  0  0  0 50]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87        53
#            1       0.71      0.57      0.64        47
#            2       0.58      0.40      0.47        48
#            3       0.68      0.64      0.66        56
#            4       0.71      0.96      0.81        50
#            5       0.80      0.82      0.81        57
#            6       1.00      0.94      0.97        51
#            7       0.78      0.98      0.87        51
#
#     accuracy                           0.77       413
#    macro avg       0.77      0.77      0.76       413
# weighted avg       0.77      0.77      0.77       413

# %%
pip install yellowbrick
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yellowbrick
from  yellowbrick.classifier import ROCAUC

def plot_ROC_curve(model, X_train, Y_train, X_test, Y_test):

    # Creating visualization with the readable labels
    visualizer = ROCAUC(model, encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas',3:'Hydro',4:'Nuclear',5:'Oil',6:'Solar',7:'Wind'})
                                        
    # Fitting to the training data first then scoring with the test data                                    
    visualizer.fit(X_train, Y_train)
    visualizer.score(X_test, Y_test)
    visualizer.show()
    
    return visualizer

# %%
# Plotting AUC ROC for Logistic Regression
plot_ROC_curve(lg,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=LogisticRegression())

# %% [markdown]
# # 2. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
Y_pred_test_dtc = dtc.predict(X_test)
Y_pred_train_dtc = dtc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,Y_pred_train_dtc))
print("Testing accuracy is ",accuracy_score(Y_test,Y_pred_test_dtc))
print(confusion_matrix(Y_test,Y_pred_test_dtc))
print(classification_report(Y_test,Y_pred_test_dtc))
# Out:
# Training accuracy is  1.0
# Testing accuracy is  0.8886198547215496
# [[50  2  0  1  0  0  0  0]
#  [ 1 33  7  3  1  2  0  0]
#  [ 2  1 36  6  0  3  0  0]
#  [ 0  4  4 46  1  1  0  0]
#  [ 0  2  0  0 48  0  0  0]
#  [ 0  1  1  1  0 53  0  1]
#  [ 0  1  0  0  0  0 50  0]
#  [ 0  0  0  0  0  0  0 51]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        53
#            1       0.75      0.70      0.73        47
#            2       0.75      0.75      0.75        48
#            3       0.81      0.82      0.81        56
#            4       0.96      0.96      0.96        50
#            5       0.90      0.93      0.91        57
#            6       1.00      0.98      0.99        51
#            7       0.98      1.00      0.99        51
#
#     accuracy                           0.89       413
#    macro avg       0.89      0.89      0.89       413
# weighted avg       0.89      0.89      0.89       413

# %%
# Plotting AUC ROC for Decision Tree Classifier
plot_ROC_curve(dtc,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for DecisionTreeClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=DecisionTreeClassifier())

# %% [markdown]
# # 3. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, Y_train)
Y_pred_test_rfc = rfc.predict(X_test)
Y_pred_train_rfc = rfc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,Y_pred_train_rfc))
print("Testing accuracy is ",accuracy_score(Y_test,Y_pred_test_rfc))
print(confusion_matrix(Y_test,Y_pred_test_rfc))
print(classification_report(Y_test,Y_pred_test_rfc))
# Out:
# Training accuracy is  1.0
# Testing accuracy is  0.9346246973365617
# [[53  0  0  0  0  0  0  0]
#  [ 3 38  4  0  2  0  0  0]
#  [ 2  1 41  2  0  2  0  0]
#  [ 0  5  4 46  1  0  0  0]
#  [ 0  0  0  0 50  0  0  0]
#  [ 0  0  0  0  0 57  0  0]
#  [ 0  0  1  0  0  0 50  0]
#  [ 0  0  0  0  0  0  0 51]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        53
#            1       0.86      0.81      0.84        47
#            2       0.82      0.85      0.84        48
#            3       0.96      0.82      0.88        56
#            4       0.94      1.00      0.97        50
#            5       0.97      1.00      0.98        57
#            6       1.00      0.98      0.99        51
#            7       1.00      1.00      1.00        51
#
#     accuracy                           0.93       413
#    macro avg       0.93      0.93      0.93       413
# weighted avg       0.94      0.93      0.93       413

# %%
# Plotting AUC ROC for Random Forest Classifier
plot_ROC_curve(rfc,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=RandomForestClassifier())

# %% [markdown]
# # 4. Support Vector Classifier

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred_test_svc = svc.predict(X_test)
Y_pred_train_svc = svc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,Y_pred_train_svc))
print("Testing accuracy is ",accuracy_score(Y_test,Y_pred_test_svc))
print(confusion_matrix(Y_test,Y_pred_test_svc))
print(classification_report(Y_test,Y_pred_test_svc))
# Out:
# Training accuracy is  0.8752271350696548
# Testing accuracy is  0.8547215496368039
# [[51  0  0  0  0  0  0  2]
#  [ 2 31  4  1  6  1  0  2]
#  [ 3  0 35  2  1  7  0  0]
#  [ 0  2 11 38  5  0  0  0]
#  [ 0  0  0  0 50  0  0  0]
#  [ 0  3  0  3  0 49  0  2]
#  [ 0  0  0  0  0  3 48  0]
#  [ 0  0  0  0  0  0  0 51]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94        53
#            1       0.86      0.66      0.75        47
#            2       0.70      0.73      0.71        48
#            3       0.86      0.68      0.76        56
#            4       0.81      1.00      0.89        50
#            5       0.82      0.86      0.84        57
#            6       1.00      0.94      0.97        51
#            7       0.89      1.00      0.94        51
#
#     accuracy                           0.85       413
#    macro avg       0.86      0.85      0.85       413
# weighted avg       0.86      0.85      0.85       413

# %%
# Plotting AUC ROC for SVC
plot_ROC_curve(svc,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for SVC'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=SVC())

# %% [markdown]
# # 5. KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
Y_pred_test_knn = knn.predict(X_test)
Y_pred_train_knn = knn.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,Y_pred_train_knn))
print("Testing accuracy is ",accuracy_score(Y_test,Y_pred_test_knn))
print(confusion_matrix(Y_test,Y_pred_test_knn))
print(classification_report(Y_test,Y_pred_test_knn))
# Out:
# Training accuracy is  0.9200484554815264
# Testing accuracy is  0.8837772397094431
# [[52  0  0  0  0  0  0  1]
#  [ 2 25  6  2  8  2  0  2]
#  [ 2  1 39  2  0  4  0  0]
#  [ 0  2  8 45  1  0  0  0]
#  [ 0  0  1  1 48  0  0  0]
#  [ 0  0  0  0  0 57  0  0]
#  [ 0  0  3  0  0  0 48  0]
#  [ 0  0  0  0  0  0  0 51]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95        53
#            1       0.89      0.53      0.67        47
#            2       0.68      0.81      0.74        48
#            3       0.90      0.80      0.85        56
#            4       0.84      0.96      0.90        50
#            5       0.90      1.00      0.95        57
#            6       1.00      0.94      0.97        51
#            7       0.94      1.00      0.97        51
#
#     accuracy                           0.88       413
#    macro avg       0.89      0.88      0.88       413
# weighted avg       0.89      0.88      0.88       413

# %%
# Plotting AUC ROC for KNN
plot_ROC_curve(knn,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for KNeighborsClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=KNeighborsClassifier())

# %% [markdown]
# # 6. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(X_train, Y_train)
Y_pred_test_gbc = gbc.predict(X_test)
Y_pred_train_gbc = gbc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,Y_pred_train_gbc))
print("Testing accuracy is ",accuracy_score(Y_test,Y_pred_test_gbc))
print(confusion_matrix(Y_test,Y_pred_test_gbc))
print(classification_report(Y_test,Y_pred_test_gbc))
# Out:
# Training accuracy is  0.9963658388855239
# Testing accuracy is  0.927360774818402
# [[53  0  0  0  0  0  0  0]
#  [ 3 39  2  1  2  0  0  0]
#  [ 2  1 42  0  1  2  0  0]
#  [ 0  4  5 44  3  0  0  0]
#  [ 0  0  0  0 50  0  0  0]
#  [ 1  0  1  0  0 54  0  1]
#  [ 0  0  1  0  0  0 50  0]
#  [ 0  0  0  0  0  0  0 51]]
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        53
#            1       0.89      0.83      0.86        47
#            2       0.82      0.88      0.85        48
#            3       0.98      0.79      0.87        56
#            4       0.89      1.00      0.94        50
#            5       0.96      0.95      0.96        57
#            6       1.00      0.98      0.99        51
#            7       0.98      1.00      0.99        51
#
#     accuracy                           0.93       413
#    macro avg       0.93      0.93      0.93       413
# weighted avg       0.93      0.93      0.93       413

# %%
# Plotting AUC ROC for GradientBoostingClassifier
plot_ROC_curve(gbc,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for GradientBoostingClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=GradientBoostingClassifier())

# %% [markdown]
# ## Cross-validation

# %%
from sklearn.model_selection import cross_val_score

# validation accuracy

model=[lg,dtc,rfc,svc,knn,gbc]

for i in model:
    for j in range(2,11):
        print('taking cv =', j)
        cr_score=cross_val_score(i, X, Y, cv=j)
        print('Cross validation score for ' , i ,' is', cr_score)
        print('Mean of Cross Val. score is ', cr_score.mean())
# Out:
# taking cv = 2
# Cross validation score for  LogisticRegression()  is [0.77325581 0.78391473]
# Mean of Cross Val. score is  0.7785852713178294
# taking cv = 3
# Cross validation score for  LogisticRegression()  is [0.77180233 0.77761628 0.77325581]
# Mean of Cross Val. score is  0.7742248062015505
# taking cv = 4
# Cross validation score for  LogisticRegression()  is [0.75968992 0.78488372 0.77713178 0.7751938 ]
# Mean of Cross Val. score is  0.7742248062015504
# taking cv = 5
# Cross validation score for  LogisticRegression()  is [0.75544794 0.76755448 0.79903148 0.77723971 0.75970874]
# Mean of Cross Val. score is  0.7717964691224524
# taking cv = 6
# Cross validation score for  LogisticRegression()  is [0.74418605 0.77906977 0.78197674 0.7877907  0.78197674 0.75      ]
# Mean of Cross Val. score is  0.7708333333333334
# taking cv = 7
# Cross validation score for  LogisticRegression()  is [0.73220339 0.78644068 0.77627119 0.78644068 0.78644068 0.76949153
#  0.7585034 ]
# ...

# %% [markdown]
# Observation
#
# - The Random Forest Classifier and Gradient Boosting Classifier are giving an accuracy of = 93.4% and 92.7 respectively(Higher than rest of the Classifiers)-
# -Comparing the cross val scores of both at the same fold 8, it is observed that random forest classifier is having 93.26% and the gradient boosting is having 91.96%
# -Hence Finalizing the Random Forest Classifier as a best mod

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

#Creating parameter list to be passed in GridSearchCV
parameters = {
    'n_estimators':[50,100,300,500],
    'criterion':['gini','entropty'],
    'max_features':['auto','log2','sqrt'],
    'max_depth':[5,10,15,20]
 
} 

GCV=GridSearchCV(estimator=RandomForestClassifier(),
                param_grid=parameters,
                cv=16,
                scoring='accuracy')

# %%
GCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=16, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropty'],
#                          'max_depth': [5, 10, 15, 20],
#                          'max_features': ['auto', 'log2', 'sqrt'],
#                          'n_estimators': [50, 100, 300, 500]},
#              scoring='accuracy')

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'n_estimators': 500}

# %%
# Checking score with best parameter
final_model=RandomForestClassifier(criterion='gini',max_depth=20,max_features='auto',n_estimators=50)
final_model.fit(X_train,Y_train)
Y_pred_test_final=final_model.predict(X_test)
print('Final Accuracy is with Random Forest Classifier = ',accuracy_score(Y_test,Y_pred_test_final))
# Out:
# Final Accuracy is with Random Forest Classifier =  0.9297820823244553

# %%
# Plotting AUC ROC for Final Model
plot_ROC_curve(final_model,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'Biomass', 1: 'Coal', 2: 'Gas', 3: 'Hydro', 4: 'Nuclear',
#                 5: 'Oil', 6: 'Solar', 7: 'Wind'},
#        estimator=RandomForestClassifier(max_depth=20, n_estimators=50))

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(max_depth=20, max_features='sqrt', n_estimators=500)

# %%
#Importing Job lib for saving the model
import joblib
joblib.dump(GCV.best_estimator_, "Global Power plant Fuel Type Prediction.pkl")
# Out:
# ['Global Power plant Fuel Type Prediction.pkl']

# %%
# Conclusion Step 
a=np.array(Y_test)
predicted=np.array(Y_pred_test_final)
df_con=pd.DataFrame({'Original':a,'Predicted':Y_pred_test_rfc}, index=range(len(a)))
df_con
# Out:
#      Original  Predicted
# 0           6          6
# 1           5          5
# 2           7          7
# 3           6          6
# 4           0          0
# ..        ...        ...
# 408         0          0
# 409         5          5
# 410         5          5
# 411         7          7
# 412         5          5
#
# [413 rows x 2 columns]

# %% [markdown]
# ## Model is saved with 93% Accuracy - the best for classification
